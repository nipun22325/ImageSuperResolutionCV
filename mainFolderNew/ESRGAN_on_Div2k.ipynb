# %%
# !git clone https://github.com/nipun22325/ImageSuperResolutionCV
# Out:
# Cloning into 'ImageSuperResolutionCV'...
# remote: Enumerating objects: 235, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 235 (delta 2), reused 10 (delta 2), pack-reused 224 (from 1)
# Receiving objects: 100% (235/235), 659.22 MiB | 16.56 MiB/s, done.
# Resolving deltas: 100% (2/2), done.
# Updating files: 100% (209/209), done.
# Filtering content: 100% (2/2), 127.66 MiB | 24.65 MiB/s, done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip '/content/drive/MyDrive/DIV2K_valid_HR.zip' -d '/content/ImageSuperResolutionCV/mainFolderNew/images/div2k/HR'
# Out:
# Archive:  /content/drive/MyDrive/DIV2K_valid_HR.zip
#    creating: /content/ImageSuperResolutionCV/mainFolder/images/div2k/HR/DIV2K_valid_HR/
#   inflating: /content/ImageSuperResolutionCV/mainFolder/images/div2k/HR/DIV2K_valid_HR/0801.png
#   inflating: /content/ImageSuperResolutionCV/mainFolder/images/div2k/HR/DIV2K_valid_HR/0802.png
#   inflating: /content/ImageSuperResolutionCV/mainFolder/images/div2k/HR/DIV2K_valid_HR/0803.png
#   inflating: /content/ImageSuperResolutionCV/mainFolder/images/div2k/HR/DIV2K_valid_HR/0804.png
#   inflating: /content/ImageSuperResolutionCV/mainFolder/images/div2k/HR/DIV2K_valid_HR/0805.png
#   inflating: /content/ImageSuperResolutionCV/mainFolder/images/div2k/HR/DIV2K_valid_HR/0806.png
#   inflating: /content/ImageSuperResolutionCV/mainFolder/images/div2k/HR/DIV2K_valid_HR/0807.png
#   inflating: /content/ImageSuperResolutionCV/mainFolder/images/div2k/HR/DIV2K_valid_HR/0808.png
# ...

# %%
# !unzip '/content/drive/MyDrive/DIV2K_valid_LR_bicubic.zip' -d '/content/ImageSuperResolutionCV/mainFolderNew/images/div2k/LRx4'
# Out:
# Archive:  /content/drive/MyDrive/DIV2K_valid_LR_bicubic.zip
#    creating: /content/ImageSuperResolutionCV/mainFolder/images/div2k/LRx4/DIV2K_valid_LR_bicubic/
#    creating: /content/ImageSuperResolutionCV/mainFolder/images/div2k/LRx4/DIV2K_valid_LR_bicubic/X4/
#   inflating: /content/ImageSuperResolutionCV/mainFolder/images/div2k/LRx4/DIV2K_valid_LR_bicubic/X4/0801x4.png
#   inflating: /content/ImageSuperResolutionCV/mainFolder/images/div2k/LRx4/DIV2K_valid_LR_bicubic/X4/0802x4.png
#   inflating: /content/ImageSuperResolutionCV/mainFolder/images/div2k/LRx4/DIV2K_valid_LR_bicubic/X4/0803x4.png
#   inflating: /content/ImageSuperResolutionCV/mainFolder/images/div2k/LRx4/DIV2K_valid_LR_bicubic/X4/0804x4.png
#   inflating: /content/ImageSuperResolutionCV/mainFolder/images/div2k/LRx4/DIV2K_valid_LR_bicubic/X4/0805x4.png
#   inflating: /content/ImageSuperResolutionCV/mainFolder/images/div2k/LRx4/DIV2K_valid_LR_bicubic/X4/0806x4.png
# ...

# %%
# !pip install lpips
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 101.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 46.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 40.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 17.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 83.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !python3 /content/ImageSuperResolutionCV/mainFolder/test-div2k-esrgan.py RRDB_ESRGAN_x4
# Out:
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: /usr/local/lib/python3.11/dist-packages/lpips/weights/v0.1/alex.pth
# Model path /content/ImageSuperResolutionCV/mainFolder/models/RRDB_ESRGAN_x4.pth.
# Testing...
# 1 0870x4
# Image: 0870x4, PSNR: 26.9893, SSIM: 0.8330, LPIPS: 0.1001
# 2 0855x4
# ...

# %%
from google.colab import files
# !zip -r /content/resultsDiv2K_ESRGAN.zip /content/ImageSuperResolutionCV/mainFolderNew/results
files.download('/content/resultsDiv2K_ESRGAN.zip')
# Out:
#   adding: content/ImageSuperResolutionCV/mainFolder/results/ (stored 0%)
#   adding: content/ImageSuperResolutionCV/mainFolder/results/0843x4_rlt.png (deflated 3%)
#   adding: content/ImageSuperResolutionCV/mainFolder/results/0862x4_rlt.png (deflated 1%)
#   adding: content/ImageSuperResolutionCV/mainFolder/results/0822x4_rlt.png (deflated 0%)
#   adding: content/ImageSuperResolutionCV/mainFolder/results/0839x4_rlt.png (deflated 1%)
#   adding: content/ImageSuperResolutionCV/mainFolder/results/0888x4_rlt.png (deflated 0%)
#   adding: content/ImageSuperResolutionCV/mainFolder/results/0831x4_rlt.png (deflated 1%)
#   adding: content/ImageSuperResolutionCV/mainFolder/results/0869x4_rlt.png (deflated 1%)
#   adding: content/ImageSuperResolutionCV/mainFolder/results/0810x4_rlt.png (deflated 0%)
#   adding: content/ImageSuperResolutionCV/mainFolder/results/0892x4_rlt.png (deflated 1%)
#   adding: content/ImageSuperResolutionCV/mainFolder/results/0865x4_rlt.png (deflated 1%)
# ...

# %%
# !python3 /content/ImageSuperResolutionCV/mainFolder/test-div2k-esrgan.py RRDB_PSNR_x4
# Out:
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: /usr/local/lib/python3.11/dist-packages/lpips/weights/v0.1/alex.pth
# Model path /content/ImageSuperResolutionCV/mainFolder/models/RRDB_PSNR_x4.pth.
# Testing...
# 1 0870x4
# Image: 0870x4, PSNR: 28.9139, SSIM: 0.8784, LPIPS: 0.2085
# 2 0855x4
# ...
